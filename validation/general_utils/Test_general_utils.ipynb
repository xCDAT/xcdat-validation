# %%
import xcdat

# %%
import cdms2
import cdutil
import numpy as np

# %%
import os

# %%
demo_data_dir = '/Users/zhang40/Documents/ACME_simulations/E3SM_v1'
demo_filename = 'TS_185001_201312.nc'
demo_file = os.path.join(demo_data_dir, demo_filename)

# %%
# Specify data_var will limit to one variable per dataset, this is useful for files with multiple vars.
ds = xcdat.open_dataset(demo_file, data_var = 'TS')
#ts_global = ds.spatial.avg().TS     
# Alternatively
ts_global = ds.xcdat.spatial_avg().TS
ts_region = ds.xcdat.spatial_avg(axis="lat").TS
# Out:
# 2021-11-05 15:50:02,030 [INFO]: dataset.py(get_inferred_var:402) >> The data variable 'TS' was inferred from the Dataset attr 'xcdat_infer' for this operation.
# 2021-11-05 15:50:02,852 [INFO]: dataset.py(get_inferred_var:402) >> The data variable 'TS' was inferred from the Dataset attr 'xcdat_infer' for this operation.

# %%
fin = cdms2.open(demo_file)
var = fin('TS')
var.shape
# Out:
# (1968, 129, 256)

# %%
#ts_1850 = ds.TS.sel(time=slice('1851-01-01 00:00:00', '1851-12-31 23:59:59'))

# %%
ts_global_cdat = cdutil.averager(var, axis="xy", weights="generate")
ts_region_cdat = cdutil.averager(var, axis="y", weights="generate")

# %%
#ts_global = ds.spatial.avg("TS", axis=["lat", "lon"])["TS"]

# %%
ts_global_diff_mean = np.mean(ts_global_cdat -  ts_global)

# %%
ts_region_diff_mean = ts_region_cdat - ts_region

# %%
points_specs = {
    # ARM sites coordinates, select nearest grid poit to ARM site coordinates
    # Each point is supplied with [latitude, longitude ,select method, description of the point]
    "sgp": [36.4, -97.5, "cob", "97.5W 36.4N Oklahoma ARM"],
    "nsa": [71.3, -156.6, "cob", "156.6W 71.3N Barrow ARM"],
    "twpc1": [-2.1, 147.4, "cob", "147.4E 2.1S Manus ARM"],
    "twpc2": [-0.5, 166.9, "cob", "166.9E 0.5S Nauru ARM"],
    "twpc3": [-12.4, 130.9, "cob", "130.9E 12.4S Darwin ARM"],
}



sgp_lat = points_specs["sgp"][0]
#sgp_lon =  (360 + points_specs["sgp"][1]) # note, convert longitude is required. 
sgp_lon = points_specs["sgp"][1]
ts = ds.TS
ts_sgp = ts.sel(lon=sgp_lon, lat=sgp_lat, method="nearest")
ts_sgp
# Out:
# <xarray.DataArray 'TS' (time: 1968)>
# array([286.13126, 285.3994 , 284.89404, ..., 294.42276, 291.47092, 289.28806],
#       dtype=float32)
# Coordinates:
#     lat      float64 36.56
#     lon      float64 0.0
#   * time     (time) object 1850-02-01 00:00:00 ... 2014-01-01 00:00:00
# Attributes:
#     units:          K
#     long_name:      Surface temperature (radiative)
#     cell_methods:   time: mean
#     cell_measures:  area: area

# %%
demo_data_dir2 = '/Users/zhang40/Documents/ACME_simulations/obs_for_e3sm_diags/time-series/TRMM_3hr/ncfiles'
demo_filename2 = 'pr_3hr_TRMM-3B43v-7_BE_gn_v20200430_*'
#demo_filename2 = 'pr_3hr_TRMM-3B43v-7_BE_gn_v20200430_201301010000-201301312100.nc'

demo_file2 = os.path.join(demo_data_dir2, demo_filename2)

# %%
ds2 = xcdat.open_mfdataset(demo_file2)

# %%
pr_global = ds2.xcdat.spatial_avg(axis=["lat", "lon"]).pr
# Out:
# 2021-11-05 16:10:50,958 [INFO]: dataset.py(get_inferred_var:402) >> The data variable 'pr' was inferred from the Dataset attr 'xcdat_infer' for this operation.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/v5/66rvtx3s2ld04xj_pz7cgtd4001nnm/T/ipykernel_92384/1036211618.py in <module>
# ----> 1 pr_global = ds2.xcdat.spatial_avg(axis=["lat", "lon"]).pr
#
# ~/miniconda3/envs/xcdat_test/lib/python3.9/site-packages/xcdat/xcdat.py in spatial_avg(self, data_var, axis, weights, lat_bounds, lon_bounds)
#      43     ) -> xr.Dataset:
#      44         obj = DatasetSpatialAverageAccessor(self._dataset)
# ---> 45         return obj.avg(data_var, axis, weights, lat_bounds, lon_bounds)
#      46
#      47     @property  # type: ignore
#
# ...

# %%
pr_global
# Out:
# <xarray.DataArray 'pr' (time: 248)>
# dask.array<truediv, shape=(248,), dtype=float64, chunksize=(248,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2013-01-01 ... 2013-01-31T21:00:00
# Attributes:
#     standard_name:  precipitation_flux
#     long_name:      Precipitation
#     comment:        includes both liquid and solid phases
#     units:          kg m-2 s-1
#     cell_methods:   area: time: mean
#     history:        2020-05-01T02:38:15Z altered by CMOR: replaced missing va...
