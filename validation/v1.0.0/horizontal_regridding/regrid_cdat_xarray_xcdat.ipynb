# %%
import matplotlib
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cdms2

# %% [markdown]
# Case 1: CDMS regrider: regrid var1 (higher resolution) toward var2 (lower resolution)
# Bilinear method works, but Conservative method created erroneous boundary around masked data.

# %%
file_name1 = '/Users/zhang40/Downloads/HadISST_CL-SST-ANN-global_test.nc'

# %%
fin = cdms2.open(file_name1)
var1 = fin('SST',squeeze=1)
print(var1.shape)
# Out:
# (720, 1440)

# %%
file_name2 = '/Users/zhang40/Downloads/HadISST_CL-SST-ANN-global_ref.nc'
fin2 = cdms2.open(file_name2)
var2 = fin2('SST',squeeze=1)

# %%
var1_linear_cdat = var1.regrid(
            var2.getGrid(),
            regridTool='esmf',
            regridMethod='bilinear',
        )

# %%
var1_conserv_cdat = var1.regrid(
            var2.getGrid(),
            regridTool='esmf',
            regridMethod='conservative',
        )

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5),
                       subplot_kw={'projection': ccrs.PlateCarree(central_longitude=180)})
#ax.coastlines()
p1 = ax.contourf(
    var1_linear_cdat.getLongitude(),
    var1_linear_cdat.getLatitude(),
    var1_linear_cdat-var2,
    transform=ccrs.PlateCarree(),
    extend="both",
    cmap = 'jet',
    levels = [-4.0, -3, -2, -1, 1, 2, 3, 4]
)
 
cbax = fig.add_axes([0.92, 0.1, 0.01, 0.7])
cbar = fig.colorbar(p1, cax=cbax)
plt.show()
# Out:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5),
                       subplot_kw={'projection': ccrs.PlateCarree(central_longitude=180)})
#ax.coastlines()
p1 = ax.contourf(
    var1_conserv_cdat.getLongitude(),
    var1_conserv_cdat.getLatitude(),
    var1_conserv_cdat-var2,
    transform=ccrs.PlateCarree(),
    extend="both",
    cmap = 'jet',
    levels = [-4.0, -3, -2, -1, 1, 2, 3, 4]
)
 
cbax = fig.add_axes([0.92, 0.1, 0.01, 0.7])
cbar = fig.colorbar(p1, cax=cbax)
plt.show()

# %%
print('maximun differencence between conserv and linear regridding: cdms', (var1_linear_cdat-var1_conserv_cdat).max())
# Out:
# maximun differencence between conserv and linear regridding: cdms 15.16215

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5),
                       subplot_kw={'projection': ccrs.PlateCarree(central_longitude=180)})
#ax.coastlines()
p1 = ax.contourf(
    var1_conserv_cdat.getLongitude(),
    var1_conserv_cdat.getLatitude(),
    var1_conserv_cdat-var1_linear_cdat,
    transform=ccrs.PlateCarree(),
    extend="both",
    cmap = 'jet',
    levels = [-4.0, -3, -2, -1, 1, 2, 3, 4]
)
 
cbax = fig.add_axes([0.92, 0.1, 0.01, 0.7])
cbar = fig.colorbar(p1, cax=cbax)
plt.show()

# %% [markdown]
# Case 2: XARRAY regridding: regrid var1 (higher resolution) toward var2 (lower resolution)
# Bilinear method works, but Conservative method requires to manually constructure a set of latitude and longitude bounds. Three examples are shown below:
# 1. Bilinearly interpolated test data using xarray dataarray
# 2. Conservatively interpolated test data using xarray datarray
# 3. Conservatively interpolated test data using cdms2 transient variable (converted to be xarray object).

# %%
import xarray as xr
import xesmf as xe
import netCDF4
import numpy

# %%
da1 = xr.open_dataset(file_name1).SST

# %%
da2 = xr.open_dataset(file_name2).SST

# %% [markdown]
# 1. Bilinearly interpolated test data using xarray dataarray

# %%
regridder = xe.Regridder(da1, da2, 'bilinear', periodic = True)
# Out:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/xarray/core/dataarray.py:784: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return key in self.data

# %%
var1_linear_xr = regridder(da1)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5),
                       subplot_kw={'projection': ccrs.PlateCarree(central_longitude=180)})
#ax.coastlines()
p1 = ax.contourf(
    var1_linear_xr['longitude'],
    var1_linear_xr['latitude'],
    var1_linear_xr-da2,
    transform=ccrs.PlateCarree(),
    extend="both",
    cmap = 'jet',
    levels = [-4.0, -3, -2, -1, 1, 2, 3, 4]
)
 
cbax = fig.add_axes([0.92, 0.1, 0.01, 0.7])
cbar = fig.colorbar(p1, cax=cbax)
ax.set_title('fig 1. Bilinearly interpolated test data using xarray dataarray')
plt.show()
# Out:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)

# %% [markdown]
# 2. Conservatively interpolated test data using xarray datarray

# %%
lon_b_var1 = var1.getLongitude().getBounds()
lon_b_1 = numpy.unique(numpy.sort(lon_b_var1.flatten())) # reform bounds array, because the bounds in the source don't appear to be correct.

lon_b_var2 = var2.getLongitude().getBounds()
lon_b_2 = numpy.unique(numpy.sort(lon_b_var2.flatten()))

lat_b_var1 = var1.getLatitude().getBounds()
lat_b_1 = numpy.unique(numpy.sort(lat_b_var1.flatten()))

lat_b_var2 = var2.getLatitude().getBounds()
lat_b_2 = numpy.unique(numpy.sort(lat_b_var2.flatten()))

# %%
test_grid_with_bounds = {'lon': da1['lon'],
                           'lat': da1['lat'],
                           #'lon_b': numpy.linspace(-180, 180, 1441),
                           #'lat_b': numpy.linspace(-90, 90, 721),
                           'lon_b': lon_b_1,
                           'lat_b': lat_b_1,
                          }

ref_grid_with_bounds = {'lon': da2['longitude'],
                           'lat': da2['latitude'],
                           #'lon_b': numpy.linspace(0, 360, 361),
                           #'lat_b': numpy.linspace(-90, 90, 181),
                           'lon_b': lon_b_2,
                           'lat_b': lat_b_2,

                          }

# %%
regridder_conserve = xe.Regridder(test_grid_with_bounds, ref_grid_with_bounds, method='conservative_normed', periodic = True)

# %%
var1_conserv_xr = regridder_conserve(da1)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5),
                       subplot_kw={'projection': ccrs.PlateCarree(central_longitude=180)})
#ax.coastlines()
p1 = ax.contourf(
    var1_conserv_xr['longitude'],
    var1_conserv_xr['latitude'],
    var1_conserv_xr-da2,
    transform=ccrs.PlateCarree(),
    extend="both",
    cmap = 'jet',
    levels = [-4.0, -3, -2, -1, 1, 2, 3, 4]
)
 
cbax = fig.add_axes([0.92, 0.1, 0.01, 0.7])
cbar = fig.colorbar(p1, cax=cbax)
ax.set_title('2. Conservatively interpolated test data using xarray datarray')
plt.show()

# %% [markdown]
# Quick way to plot a map

# %%
(var1_linear_xr-var1_conserv_xr).plot()

# %%
print('maximun differencence between conserv and linear difference', (var1_linear_xr-var1_conserv_xr).max())
# Out:
# maximun differencence between conserv and linear difference <xarray.DataArray ()>
# array(0.7771759, dtype=float32)

# %% [markdown]
# Case 3. Conservatively interpolated test data using cdms2 transient variable (converted to be xarray object).

# %%
var1_xr = xr.DataArray.from_cdms2(var1)   #need to convert to xarray dataarray to be able to keep metadata 
var2_xr = xr.DataArray.from_cdms2(var2)
var1_xr = xr.where(var1_xr<var1._FillValue, var1_xr, numpy.nan)# Need to convert missing values to numpy nan values.
var2_xr = xr.where(var2_xr<var1._FillValue, var2_xr, numpy.nan)

# %%
var1_grid_with_bounds = {'lon': var1.getLongitude(),
                           'lat': var1.getLatitude(),
                           'lon_b': lon_b_1,
                           'lat_b': lat_b_1,
                           #'lon_b': numpy.linspace(-180, 180, 1441),
                           #'lat_b': numpy.linspace(-90, 90, 721),
                          }

var2_grid_with_bounds = {'lon': var2.getLongitude(),
                           'lat': var2.getLatitude(),
                           'lon_b': lon_b_2,
                           'lat_b': lat_b_2,
                           #'lon_b': numpy.linspace(0, 360, 361),
                           #'lat_b': numpy.linspace(-90, 90, 181),
                          }

# %%
regridder_conserve_var = xe.Regridder(var1_grid_with_bounds, var2_grid_with_bounds, method='conservative_normed')

# %%
var1_conserve_cdat_xr = regridder_conserve_var(var1_xr)
# Out:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/xesmf/frontend.py:594: UserWarning: Using dimensions ('lat', 'lon') from data variable SST as the horizontal dimensions for the regridding.
#   warnings.warn(

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5),
                       subplot_kw={'projection': ccrs.PlateCarree(central_longitude=180)})
#ax.coastlines()
p1 = ax.contourf(
    var1_conserve_cdat_xr['lon'],
    var1_conserve_cdat_xr['lat'],
    var1_conserve_cdat_xr - var2,
    transform=ccrs.PlateCarree(),
    extend="both",
    cmap = 'jet',
    levels = [-4.0, -3, -2, -1, 1, 2, 3, 4]
)
 
cbax = fig.add_axes([0.92, 0.1, 0.01, 0.7])
cbar = fig.colorbar(p1, cax=cbax)
ax.set_title('3. Conservatively interpolated test data using cdms2 transient variable (converted to be xarray object).')
plt.show()
# Out:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)

# %% [markdown]
# Case 4: XCDAT regridding: regrid var1 (higher resolution) toward var2 (lower resolution)
# Difference between linearly regridded var1 and conservatively regridded var1 is huge. See plot at bottom

# %%
import xcdat
from xcdat.regridder import grid

# %%
dsx1 = xcdat.open_dataset(file_name1)
# Re-generating bounds, since the original lat bounds are not correct
dsx1 = dsx1.drop_vars(["lat_bnds", "lon_bnds"])
dsx1 = dsx1.bounds.add_missing_bounds()

# %%
dsx2 = xcdat.open_dataset(file_name2)
# Re-generating bounds, since the original lat bounds are not correct
dsx2 = dsx2.drop_vars(["latitude_bnds", "longitude_bnds"])
dsx2 = dsx2.bounds.add_missing_bounds()

# %%
var1_linear_xcdat = dsx1.regridder.horizontal('SST', dsx2, 'xesmf', method='bilinear',periodic = True)

# %%
var1_linear_xcdat.SST.plot()

# %%
var1_conserv_xcdat = dsx1.regridder.horizontal('SST', dsx2, 'xesmf', method='conservative_normed', periodic = True)

# %%
(var1_linear_xcdat.SST-var1_conserv_xcdat.SST).max()
# Out:
# <xarray.DataArray 'SST' ()>
# array(0.7771759, dtype=float32)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5),
                       subplot_kw={'projection': ccrs.PlateCarree(central_longitude=180)})
#ax.coastlines()
p1 = ax.contourf(
    dsx2['longitude'],
    dsx2['latitude'],
    var1_linear_xcdat.SST-dsx2.SST,
    transform=ccrs.PlateCarree(),
    extend="both",
    cmap = 'jet',
    levels = [-4.0, -3, -2, -1, 1, 2, 3, 4]
)
 
cbax = fig.add_axes([0.92, 0.1, 0.01, 0.7])
cbar = fig.colorbar(p1, cax=cbax)
ax.set_title('fig 4a. Bilinearly interpolated test data using xcdat')
plt.show()
# Out:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:836: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)
# /Users/zhang40/miniconda3/envs/xcdat_test_dev/lib/python3.9/site-packages/cartopy/crs.py:982: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings.extend(multi_line_string)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,5),
                       subplot_kw={'projection': ccrs.PlateCarree(central_longitude=180)})
#ax.coastlines()
p1 = ax.contourf(
    dsx2['longitude'],
    dsx2['latitude'],
    var1_conserv_xcdat.SST-dsx2.SST,
    transform=ccrs.PlateCarree(),
    extend="both",
    cmap = 'jet',
    levels = [-4.0, -3, -2, -1, 1, 2, 3, 4]
)
 
cbax = fig.add_axes([0.92, 0.1, 0.01, 0.7])
cbar = fig.colorbar(p1, cax=cbax)
ax.set_title('fig 4b. Bilinearly interpolated test data using xcdat')
plt.show()

# %%
(var1_linear_xcdat.SST - var1_conserv_xcdat.SST).plot()

# %%
(var1_conserv_xr - var1_conserv_xcdat.SST).plot()

# %%
print('maximun differencence between conserv and linear difference: xcdat', (var1_linear_xcdat-var1_conserv_xcdat).max())
# Out:
# maximun differencence between conserv and linear difference: xcdat <xarray.Dataset>
# Dimensions:   ()
# Data variables:
#     SST       float32 0.7772
#     lon_bnds  float64 0.0
#     lat_bnds  float64 0.0

# %%
(var1_linear_xcdat-var1_linear_xr).max()
# Out:
# <xarray.Dataset>
# Dimensions:   ()
# Data variables:
#     SST       float32 0.0
#     lon_bnds  float64 360.2
#     lat_bnds  float64 90.16

# %%
(var1_conserv_xcdat-var1_conserv_xr).max()
# Out:
# <xarray.Dataset>
# Dimensions:   ()
# Data variables:
#     SST       float32 0.0
#     lon_bnds  float64 360.1
#     lat_bnds  float64 90.08
