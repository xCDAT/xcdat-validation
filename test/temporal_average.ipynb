# %% [markdown]
# # Temporal Average Testing
#
# Test procedure:
# - XCDAT is source-installed from branch `feature/201-temporal-mean`
# - PR: https://github.com/xCDAT/xcdat/pull/236
#
# ## Load test data

# %%
import os

# %%
demo_data_dir = '../tutorials/demo_data/CMIP5_demo_data'
demo_filename = 'ts_Amon_ACCESS1-0_historical_r1i1p1_185001-200512.nc'
demo_file = os.path.join(demo_data_dir, demo_filename)

# %%
import xcdat

# %%
ds = xcdat.open_dataset(demo_file)

# %%
ts = ds.ts

# %%
ts
# Out:
# <xarray.DataArray 'ts' (time: 1872, lat: 145, lon: 192)>
# [52116480 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-16T12:00:00 ... 2005-12-16T12:00:00
#   * lat      (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
# Attributes:
#     standard_name:     surface_temperature
#     long_name:         Surface Temperature
#     comment:           ""skin"" temperature (i.e., SST for open ocean)
#     units:             K
#     cell_methods:      time: mean
#     cell_measures:     area: areacella
#     history:           2012-01-17T03:16:09Z altered by CMOR: replaced missing...
#     associated_files:  baseURL: http://cmip-pcmdi.llnl.gov/CMIP5/dataLocation...

# %% [markdown]
# ## 1. Temporal Average
#
# ### 1.1 Month

# %%
ds_ave_month = ds.temporal.average("ts", freq="month")

# %%
ds_ave_month.ts.shape
# Out:
# (145, 192)

# %%
ds_ave_month
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 145, bnds: 2, lon: 192)
# Coordinates:
#   * lat       (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon       (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds  (lat, bnds) float64 ...
#     lon_bnds  (lon, bnds) float64 ...
#     ts        (lat, lon) float64 224.6 224.6 224.6 224.6 ... 253.8 253.8 253.8
# Attributes: (12/28)
#     institution:            CSIRO (Commonwealth Scientific and Industrial Res...
#     institute_id:           CSIRO-BOM
#     experiment_id:          historical
#     source:                 ACCESS1-0 2011. Atmosphere: AGCM v1.0 (N96 grid-p...
#     model_id:               ACCESS1-0
#     forcing:                GHG, Oz, SA, Sl, Vl, BC, OC, (GHG = CO2, N2O, CH4...
#     ...                     ...
#     table_id:               Table Amon (27 April 2011) 9c851218e3842df9a62ef3...
#     title:                  ACCESS1-0 model output prepared for CMIP5 historical
#     parent_experiment:      pre-industrial control
#     modeling_realm:         atmos
#     realization:            1
#     cmor_version:           2.8.0

# %%
ds_ave_month.ts.plot()

# %% [markdown]
# ### 1.2 Season

# %%
ds_ave_season = ds.temporal.average("ts", freq="season")

# %%
ds_ave_season.ts.shape
# Out:
# (145, 192)

# %%
ds_ave_season
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 145, bnds: 2, lon: 192)
# Coordinates:
#   * lat       (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon       (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds  (lat, bnds) float64 ...
#     lon_bnds  (lon, bnds) float64 ...
#     ts        (lat, lon) float64 224.7 224.7 224.7 224.7 ... 253.8 253.8 253.8
# Attributes: (12/28)
#     institution:            CSIRO (Commonwealth Scientific and Industrial Res...
#     institute_id:           CSIRO-BOM
#     experiment_id:          historical
#     source:                 ACCESS1-0 2011. Atmosphere: AGCM v1.0 (N96 grid-p...
#     model_id:               ACCESS1-0
#     forcing:                GHG, Oz, SA, Sl, Vl, BC, OC, (GHG = CO2, N2O, CH4...
#     ...                     ...
#     table_id:               Table Amon (27 April 2011) 9c851218e3842df9a62ef3...
#     title:                  ACCESS1-0 model output prepared for CMIP5 historical
#     parent_experiment:      pre-industrial control
#     modeling_realm:         atmos
#     realization:            1
#     cmor_version:           2.8.0

# %%
ds_ave_season.ts.plot()

# %% [markdown]
# ### 1.3 Year

# %%
ds_ave_year = ds.temporal.average("ts", freq="year")

# %%
ds_ave_year.ts.shape
# Out:
# (145, 192)

# %%
ds_ave_year
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 145, bnds: 2, lon: 192)
# Coordinates:
#   * lat       (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon       (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds  (lat, bnds) float64 ...
#     lon_bnds  (lon, bnds) float64 ...
#     ts        (lat, lon) float64 224.6 224.6 224.6 224.6 ... 253.9 253.9 253.9
# Attributes: (12/28)
#     institution:            CSIRO (Commonwealth Scientific and Industrial Res...
#     institute_id:           CSIRO-BOM
#     experiment_id:          historical
#     source:                 ACCESS1-0 2011. Atmosphere: AGCM v1.0 (N96 grid-p...
#     model_id:               ACCESS1-0
#     forcing:                GHG, Oz, SA, Sl, Vl, BC, OC, (GHG = CO2, N2O, CH4...
#     ...                     ...
#     table_id:               Table Amon (27 April 2011) 9c851218e3842df9a62ef3...
#     title:                  ACCESS1-0 model output prepared for CMIP5 historical
#     parent_experiment:      pre-industrial control
#     modeling_realm:         atmos
#     realization:            1
#     cmor_version:           2.8.0

# %%
ds_ave_year.ts.plot()

# %% [markdown]
# ### 1.4 Day

# %%
ds_ave_day = ds.temporal.average("ts", freq="day")

# %%
ds_ave_day.ts.shape
# Out:
# (145, 192)

# %%
ds_ave_day
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 145, bnds: 2, lon: 192)
# Coordinates:
#   * lat       (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon       (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds  (lat, bnds) float64 ...
#     lon_bnds  (lon, bnds) float64 ...
#     ts        (lat, lon) float64 230.8 230.8 230.8 230.8 ... 246.3 246.3 246.3
# Attributes: (12/28)
#     institution:            CSIRO (Commonwealth Scientific and Industrial Res...
#     institute_id:           CSIRO-BOM
#     experiment_id:          historical
#     source:                 ACCESS1-0 2011. Atmosphere: AGCM v1.0 (N96 grid-p...
#     model_id:               ACCESS1-0
#     forcing:                GHG, Oz, SA, Sl, Vl, BC, OC, (GHG = CO2, N2O, CH4...
#     ...                     ...
#     table_id:               Table Amon (27 April 2011) 9c851218e3842df9a62ef3...
#     title:                  ACCESS1-0 model output prepared for CMIP5 historical
#     parent_experiment:      pre-industrial control
#     modeling_realm:         atmos
#     realization:            1
#     cmor_version:           2.8.0

# %%
ds_ave_day.ts.plot()

# %% [markdown]
# ### 1.5 Hour

# %%
ds_ave_hour = ds.temporal.average("ts", freq="hour")

# %%
ds_ave_hour.ts.shape
# Out:
# (145, 192)

# %%
ds_ave_hour.ts.plot()

# %% [markdown]
# ## 2. Compare temporal averages that use different `freq` option

# %%
(ds_ave_year.ts - ds_ave_month.ts).plot()

# %%
(ds_ave_season.ts - ds_ave_month.ts).plot()

# %%
(ds_ave_day.ts - ds_ave_month.ts).plot()

# %%
(ds_ave_hour.ts - ds_ave_month.ts).plot()

# %% [markdown]
# ## 2. Group Average

# %% [markdown]
# ### 2.1 Month

# %%
ds_gra_month = ds.temporal.group_average("ts", freq="month")

# %%
ds_gra_month.ts.shape
# Out:
# (1872, 145, 192)

# %%
(ds_gra_month.ts[0]-ds.ts[0]).plot()

# %% [markdown]
# ### 2.2 Year

# %%
ds_gra_year = ds.temporal.group_average("ts", freq="year")

# %%
ds_gra_year.ts.shape
# Out:
# (156, 145, 192)

# %% [markdown]
# ### 2.3 Season

# %%
ds_gra_season = ds.temporal.group_average("ts", freq="season")

# %%
ds_gra_season.ts.shape
# Out:
# (625, 145, 192)

# %%
ds_gra_season
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 145, bnds: 2, lon: 192, time: 625)
# Coordinates:
#   * lat       (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon       (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
#   * time      (time) datetime64[ns] 1850-01-01 1850-04-01 ... 2006-01-01
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds  (lat, bnds) float64 ...
#     lon_bnds  (lon, bnds) float64 ...
#     ts        (time, lat, lon) float32 245.8 245.8 245.8 ... 248.2 248.2 248.2
# Attributes: (12/28)
#     institution:            CSIRO (Commonwealth Scientific and Industrial Res...
#     institute_id:           CSIRO-BOM
#     experiment_id:          historical
#     source:                 ACCESS1-0 2011. Atmosphere: AGCM v1.0 (N96 grid-p...
#     model_id:               ACCESS1-0
#     forcing:                GHG, Oz, SA, Sl, Vl, BC, OC, (GHG = CO2, N2O, CH4...
#     ...                     ...
#     table_id:               Table Amon (27 April 2011) 9c851218e3842df9a62ef3...
#     title:                  ACCESS1-0 model output prepared for CMIP5 historical
#     parent_experiment:      pre-industrial control
#     modeling_realm:         atmos
#     realization:            1
#     cmor_version:           2.8.0

# %%
season_config_dict = {"dec_mode": "DJF", "drop_incomplete_djf": True}
ds_gra_season2 = ds.temporal.group_average("ts", freq="season", season_config=season_config_dict)

# %%
ds_gra_season2.ts.shape
# Out:
# (623, 145, 192)

# %%
ds_gra_season2
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 145, lon: 192, bnds: 2, time: 623)
# Coordinates:
#   * lat       (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#   * lon       (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
#   * time      (time) datetime64[ns] 1850-04-01 1850-07-01 ... 2005-10-01
# Dimensions without coordinates: bnds
# Data variables:
#     lat_bnds  (lat, bnds) float64 ...
#     lon_bnds  (lon, bnds) float64 ...
#     ts        (time, lat, lon) float32 216.7 216.7 216.7 ... 260.4 260.4 260.4
# Attributes: (12/28)
#     institution:            CSIRO (Commonwealth Scientific and Industrial Res...
#     institute_id:           CSIRO-BOM
#     experiment_id:          historical
#     source:                 ACCESS1-0 2011. Atmosphere: AGCM v1.0 (N96 grid-p...
#     model_id:               ACCESS1-0
#     forcing:                GHG, Oz, SA, Sl, Vl, BC, OC, (GHG = CO2, N2O, CH4...
#     ...                     ...
#     table_id:               Table Amon (27 April 2011) 9c851218e3842df9a62ef3...
#     title:                  ACCESS1-0 model output prepared for CMIP5 historical
#     parent_experiment:      pre-industrial control
#     modeling_realm:         atmos
#     realization:            1
#     cmor_version:           2.8.0

# %% [markdown]
# ### 2.4 Day

# %%
ds_gra_day = ds.temporal.group_average("ts", freq="day")

# %%
ds_gra_day.ts.shape
# Out:
# (1872, 145, 192)

# %%
ds_gra_hour.ts[0] - ds_gra_month.ts[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 ds_gra_hour.ts[0] - ds_gra_month.ts[0]
#
# NameError: name 'ds_gra_hour' is not defined

# %% [markdown]
# ### 2.5 Hour

# %%
ds_gra_hour = ds.temporal.group_average("ts", freq="hour")

# %%
ds_gra_hour.ts.shape

# %%
ds_gra_hour.ts[0] - ds_gra_day.ts[0]
